# %%
# %python
files = dbutils.fs.ls("dbfs:/mnt/demo-datasets/bookstore")
display(files)

# %%
# %sql
select count(*) from riskanalytics_devv.bronze.books_bronze

# %%
# %sql
select count(*) from riskanalytics_devv.bronze.books_silver

# %%
# %sql
select count(*) from riskanalytics_devv.bronze.author_counts_state;

# %%
# %sql
select * from riskanalytics_devv.bronze.cn_daily_customer_books;

# %%
# %sql
select count(*) from riskanalytics_devv.bronze.cn_daily_customer_books;

# %%
# %sql
select count(*) from riskanalytics_devv.bronze.fr_daily_customer_books;
